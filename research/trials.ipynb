# %%
d={"key":"val","key1":"val1"}

# %%
from box import ConfigBox

# %%
d2 = ConfigBox({"key":"val","key1":"val1"})

# %%
d2.key1
# Out:
# 'val1'

# %%
#ensure annotations

def get_product(x:int,y:int) ->int:
    return x*y

# %%
get_product(x=2,y=3)
# Out:
# 6

# %% [markdown]
# # Download Data from Google Drive

# %%
import gdown

# %%
url = "https://drive.google.com/file/d/1QgybKmyZuxVVlDPHFDAe_E1l8FLOwHVk/view?usp=sharing"
file_id=url.split("/")[-2]
file_id
# Out:
# '1QgybKmyZuxVVlDPHFDAe_E1l8FLOwHVk'

# %%
prefix="https://drive.google.com/uc?/export=download&id="
gdown.download(prefix+file_id,"Kidney_CT_Scan_data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1QgybKmyZuxVVlDPHFDAe_E1l8FLOwHVk
# From (redirected): https://drive.google.com/uc?id=1QgybKmyZuxVVlDPHFDAe_E1l8FLOwHVk&confirm=t&uuid=ad4c4b1e-514a-4923-8567-1bafb9a2ae5a
# To: d:\Data Scientist Project\Kidney-Disease-Classification Using DL\research\Kidney_CT_Scan_data.zip
# 100%|██████████| 1.63G/1.63G [02:28<00:00, 10.9MB/s]
# 'Kidney_CT_Scan_data.zip'
